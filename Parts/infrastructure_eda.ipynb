# %%
import scipy.stats as stats
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Table of Contents
# - [Reading in Data](#read)
# - [Disease EDA & Cleaning](#eda)
#     - [Cholera EDA & Cleaning](#cholera)
#     - [Ebola EDA & Cleaning](#ebola)
#     - [Malaria EDA & Cleaning](#malaria)
#     - [Meningitis EDA & Cleaning](#meningitis)
#     - [Tuberculosis EDA & Cleaning](#tuberculosis)
#     - [Zika EDA & Cleaning](#zika)
#     - [Tetanus EDA & Cleaning](#tetanus)
#     - [Rubella EDA & Cleaning](#rubella)
#     - [Pertussis EDA & Cleaning](#pert)
#     - [Mumps EDA & Cleaning](#mumps)
#     - [Measles EDA & Cleaning](#measles)
# - [EDA Findings](#find)
# - [Selecting Countries for Modeling](#select)
#     - [Cholera COV](#chol_cov)
#     - [Malaria COV](#malaria_cov)
#     - [Meningitis COV](#men_cov)
#     - [Tuberculosis COV](#tb_cov)
#     - [Tetanus COV](#tet_cov)
#     - [Rubella COV](#rub_cov)
#     - [Pertussis COV](#pert_cov)
#     - [Mumps COV](#mumps_cov)
#     - [Measles COV](#measles_cov)
#
# - [COV Findings and Country Selection](#select2)

# %% [markdown]
# # Infrastructure EDA
#
# The goal of EDA here will be to examine which datasets are feasible for our problem at hand. We need a dataset that covers a wide range of countries and data for at least 20 years. Additionally we need to carefully examine the units for each indicator as we will most likely need to convert them to a standard unit.
#
# Once cleaned we will calculate the Coeffecient of Variation (COV) for our infrastructure metrics over time for each country. Countries with high COV may be politically unstable or have exhibited a large change in spending and have drastically changing budgets, whereas countries with low COV will have very stable governments. The ambiguity in this metric will mean that it will not be weighted heavily when it comes to selecting countries, but rather to guage the stability/volatility of a country relative to other countries.
#
# There is also the issue of multicolinearity between healthcare spending and the healthcare inputs of each dataset. I will likely just include healthcare spending since that dataset has the most robust data compared to the inputs dataset. Ideally we would like to have data on specific inputs for every country however countries that are relatively unstable politically and infrastructure wise have only recently started reporting these statistics.

# %%
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %%
pd.set_option('display.max_rows', 500)

# %%
infra = pd.read_csv('../Data/Infrastructure/infrastructure_1.csv')

# %%
health = pd.read_csv('../Data/Infrastructure/Health_1.csv')

# %%
hosp_count = pd.read_csv('../Data/Infrastructure/healthcare_hospitalscount.csv')

# %%
doc_count = pd.read_csv('../Data/Infrastructure/docs_per1000.csv')

# %%
nurse_count = pd.read_csv('../Data/Infrastructure/nurses_per1000.csv')

# %%
pharm_spend = pd.read_csv('../Data/Infrastructure/pharm_uspercap.csv')

# %%
h_tech = pd.read_csv('../Data/Infrastructure/healthcare_tech.csv')

# %%
h_workers = pd.read_csv('../Data/Infrastructure/healthcare_workers.csv')

# %%
h_spend = pd.read_csv('../Data/Infrastructure/healthcare_expenditure.csv')

# %% [markdown]
# ## Infrastructure
#
# #### Varying Units

# %%
infra.head()
# Out:
#   Country Name Country Code                                    Indicator Name  \
# 0        Aruba          ABW      ICT goods exports (% of total goods exports)
# 1        Aruba          ABW         ICT goods imports (% total goods imports)
# 2        Aruba          ABW  Individuals using the Internet (% of population)
# 3        Aruba          ABW    Secure Internet servers (per 1 million people)
# 4        Aruba          ABW                           Secure Internet servers
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 0  TX.VAL.ICTG.ZS.UN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.404431
# 1  TM.VAL.ICTG.ZS.UN   NaN   NaN   NaN   NaN   NaN   NaN  ...   4.764945
# 2     IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  62.000000
# 3     IT.NET.SECR.P6   NaN   NaN   NaN   NaN   NaN   NaN  ...  88.522559
# 4        IT.NET.SECR   NaN   NaN   NaN   NaN   NaN   NaN  ...   9.000000
#
#          2011        2012        2013        2014        2015         2016  \
# 0    0.419583    0.713791    0.412533    0.933620    0.542872     1.038984
# 1    4.627908    4.420786    5.268659    5.243941    5.734922     4.918148
# 2   69.000000   74.000000   78.900000   83.780000   88.661227    93.542454
# 3  127.393528  253.510140  426.526042  568.543180  757.132862  1172.858342
# 4   13.000000   26.000000   44.000000   59.000000   79.000000   123.000000
#
#          2017         2018  2019
# 0    1.185680          NaN   NaN
# 1    4.854330          NaN   NaN
# 2   97.170000          NaN   NaN
# 3  977.544939  1152.628844   NaN
# 4  103.000000   122.000000   NaN
#
# [5 rows x 64 columns]

# %%
#infra.dtypes

# %%
#counting nulls for each
#infra.isnull().sum()

# %%
#checked unique countries
#infra['Country Name'].unique()

# %%
#checked unique indicators
#infra['Indicator Name'].unique()

# %%
#dropping columns I don't need
infra.drop(axis = 0, columns = ['Country Code', 'Indicator Code'], inplace = True)

# %%
#Setting the index to Country Name
infra = infra.set_index('Country Name')

# %%
infra.head()
# Out:
#                                                 Indicator Name  1960  1961  \
# Country Name
# Aruba             ICT goods exports (% of total goods exports)   NaN   NaN
# Aruba                ICT goods imports (% total goods imports)   NaN   NaN
# Aruba         Individuals using the Internet (% of population)   NaN   NaN
# Aruba           Secure Internet servers (per 1 million people)   NaN   NaN
# Aruba                                  Secure Internet servers   NaN   NaN
#
#               1962  1963  1964  1965  1966  1967  1968  ...       2010  \
# Country Name                                            ...
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   0.404431
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   4.764945
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  62.000000
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...  88.522559
# Aruba          NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   9.000000
#
#                     2011        2012        2013        2014        2015  \
# Country Name
# Aruba           0.419583    0.713791    0.412533    0.933620    0.542872
# Aruba           4.627908    4.420786    5.268659    5.243941    5.734922
# Aruba          69.000000   74.000000   78.900000   83.780000   88.661227
# Aruba         127.393528  253.510140  426.526042  568.543180  757.132862
# Aruba          13.000000   26.000000   44.000000   59.000000   79.000000
#
#                      2016        2017         2018  2019
# Country Name
# Aruba            1.038984    1.185680          NaN   NaN
# Aruba            4.918148    4.854330          NaN   NaN
# Aruba           93.542454   97.170000          NaN   NaN
# Aruba         1172.858342  977.544939  1152.628844   NaN
# Aruba          123.000000  103.000000   122.000000   NaN
#
# [5 rows x 61 columns]

# %%
infra.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/infra_clean.csv', index = True)

# %% [markdown]
# **Notes**: Lots of nulls for early data because they likely did not have the means to record such data in the 70s and 80s. Should also be noted there are a lot of indicators here, will likely have to handpick which ones I will use.

# %% [markdown]
# ### Infrastructure COV

# %%
#finding total COV for a row, this does COV for each individual indicator
infra['COV'] = (infra.std(axis = 1))/(infra.mean(axis=1))

# %%
#we are grouping each country and summing all their COV for each indicator
infra_total_cov = infra.groupby('Country Name')['COV'].sum()

# %%
#converting to dataframe
infra_total_cov = pd.DataFrame(data=infra_total_cov)

# %%
infra_order = infra_total_cov.sort_values(by ='COV' , ascending=False)

# %%
infra_order
# Out:
#                                                           COV
# Country Name
# Cambodia                                            38.780142
# Indonesia                                           35.355332
# China                                               35.069553
# Cameroon                                            33.977386
# Vietnam                                             33.074640
# Brazil                                              33.037385
# India                                               32.921431
# Sri Lanka                                           32.328129
# Nigeria                                             32.291814
# Mozambique                                          31.382685
# Philippines                                         31.263558
# Myanmar                                             31.108013
# Tanzania                                            31.070249
# Ethiopia                                            30.307800
# Peru                                                30.158154
# Bangladesh                                          30.057067
# Turkey                                              29.975888
# Algeria                                             29.730952
# Sudan                                               29.631659
# Nepal                                               29.536912
# Iran, Islamic Rep.                                  29.294712
# Malaysia                                            28.863849
# Late-demographic dividend                           28.742581
# East Asia & Pacific (IDA & IBRD countries)          28.558674
# Albania                                             28.511274
# Ghana                                               28.399849
# Thailand                                            28.352708
# East Asia & Pacific (excluding high income)         28.292260
# Colombia                                            28.127636
# Jordan                                              27.863809
# South Africa                                        27.767373
# Bolivia                                             27.629758
# Mauritius                                           27.592407
# South Asia (IDA & IBRD)                             27.588816
# South Asia                                          27.588816
# Moldova                                             27.513375
# Iraq                                                27.511161
# Ecuador                                             27.350706
# Zambia                                              27.290333
# Romania                                             27.031716
# Togo                                                26.950047
# Mexico                                              26.645397
# Bulgaria                                            26.515309
# Morocco                                             26.450318
# Pakistan                                            26.351919
# Kenya                                               26.332878
# Kazakhstan                                          26.256443
# Guatemala                                           25.959879
# Upper middle income                                 25.806247
# Panama                                              25.764707
# Lebanon                                             25.724709
# Armenia                                             25.715534
# Egypt, Arab Rep.                                    25.706135
# Georgia                                             25.513220
# Syrian Arab Republic                                25.502790
# Argentina                                           25.331675
# Honduras                                            25.108053
# Russian Federation                                  24.897804
# Uganda                                              24.818763
# Tajikistan                                          24.646054
# Cuba                                                24.443829
# Senegal                                             24.361384
# Cote d'Ivoire                                       24.269192
# Gambia, The                                         24.095679
# Tunisia                                             23.963259
# Slovak Republic                                     23.844305
# Uruguay                                             23.722706
# Burkina Faso                                        23.676396
# Rwanda                                              23.659281
# Middle income                                       23.654134
# Dominican Republic                                  23.624185
# Zimbabwe                                            23.612021
# Congo, Rep.                                         23.585990
# Venezuela, RB                                       23.558310
# Bahrain                                             23.472610
# IBRD only                                           23.339657
# Madagascar                                          23.159172
# Haiti                                               23.134439
# Lithuania                                           22.981897
# Lao PDR                                             22.962500
# Kyrgyz Republic                                     22.816311
# Gabon                                               22.780410
# Paraguay                                            22.771039
# Yemen, Rep.                                         22.734506
# Mali                                                22.543486
# Ukraine                                             22.491394
# Somalia                                             22.383839
# Chile                                               22.353247
# Botswana                                            22.347709
# East Asia & Pacific                                 22.334855
# Azerbaijan                                          22.184325
# Latvia                                              22.145337
# Hungary                                             22.134215
# Iceland                                             22.119873
# Benin                                               21.912456
# Afghanistan                                         21.891005
# Ireland                                             21.793115
# Congo, Dem. Rep.                                    21.786209
# Portugal                                            21.416973
# Low & middle income                                 21.411002
# Costa Rica                                          21.388735
# Belarus                                             21.365460
# IDA & IBRD total                                    21.213841
# Qatar                                               21.179568
# Bosnia and Herzegovina                              21.148276
# Namibia                                             21.137096
# Singapore                                           21.027904
# Lower middle income                                 21.005128
# Estonia                                             21.004293
# Latin America & the Caribbean (IDA & IBRD count...  20.983087
# Sierra Leone                                        20.946081
# Latin America & Caribbean (excluding high income)   20.848593
# Latin America & Caribbean                           20.674589
# Nicaragua                                           20.655294
# United Kingdom                                      20.471446
# Finland                                             20.465638
# Niger                                               20.463283
# Early-demographic dividend                          20.461808
# Mongolia                                            20.434270
# Korea, Rep.                                         20.345549
# Djibouti                                            20.342541
# Spain                                               20.337509
# Libya                                               20.291851
# Belize                                              20.242704
# Malta                                               20.184826
# Guinea                                              20.174376
# Israel                                              20.167944
# Jamaica                                             20.005210
# United Arab Emirates                                19.971959
# Lesotho                                             19.705115
# Switzerland                                         19.543175
# Maldives                                            19.480124
# Oman                                                19.385160
# Burundi                                             19.379066
# North Macedonia                                     19.344165
# Poland                                              19.295780
# Angola                                              19.283395
# France                                              19.212423
# IDA blend                                           18.987000
# Denmark                                             18.817777
# Cyprus                                              18.602035
# Malawi                                              18.558815
# Luxembourg                                          18.462083
# El Salvador                                         18.265639
# Turkmenistan                                        18.183942
# Germany                                             18.151833
# Italy                                               18.112082
# Uzbekistan                                          18.104516
# Sweden                                              18.083800
# Saudi Arabia                                        18.076580
# Greece                                              18.016655
# Czech Republic                                      17.979293
# Brunei Darussalam                                   17.973454
# New Zealand                                         17.959307
# Netherlands                                         17.903133
# Belgium                                             17.617649
# Papua New Guinea                                    17.510661
# Trinidad and Tobago                                 17.482093
# Samoa                                               17.225917
# Slovenia                                            17.156906
# Japan                                               17.051224
# Croatia                                             16.983535
# Guyana                                              16.933955
# Bhutan                                              16.856145
# Equatorial Guinea                                   16.802901
# World                                               16.762106
# Canada                                              16.711701
# Middle East & North Africa                          16.710200
# Liberia                                             16.603886
# Vanuatu                                             16.263394
# Sao Tome and Principe                               16.239827
# OECD members                                        16.207129
# Central Europe and the Baltics                      16.083462
# United States                                       16.074298
# IDA total                                           16.046753
# Comoros                                             16.019905
# Middle East & North Africa (IDA & IBRD countries)   15.944623
# European Union                                      15.819457
# Arab World                                          15.787900
# Europe & Central Asia (excluding high income)       15.764854
# Seychelles                                          15.763435
# High income                                         15.633250
# Austria                                             15.595720
# Norway                                              15.583254
# Hong Kong SAR, China                                15.560185
# Suriname                                            15.418788
# Mauritania                                          15.399482
# Middle East & North Africa (excluding high income)  15.386192
# Cabo Verde                                          15.160708
# Fiji                                                15.123254
# Australia                                           15.047330
# Dominica                                            15.018128
# Tonga                                               14.976052
# Kiribati                                            14.839489
# Eswatini                                            14.829987
# IDA only                                            14.826232
# Euro area                                           14.622661
# Guinea-Bissau                                       14.614693
# Europe & Central Asia (IDA & IBRD countries)        14.597797
# Chad                                                14.496921
# Least developed countries: UN classification        14.461221
# Europe & Central Asia                               14.420431
# Kuwait                                              14.020072
# Central African Republic                            13.976199
# Serbia                                              13.951950
# Low income                                          13.944522
# Eritrea                                             13.888225
# Pre-demographic dividend                            13.830829
# Small states                                        13.753320
# Solomon Islands                                     13.709883
# Heavily indebted poor countries (HIPC)              13.661538
# Macao SAR, China                                    13.635008
# Korea, Dem. People’s Rep.                           13.615698
# Barbados                                            13.588524
# Marshall Islands                                    13.479795
# Other small states                                  13.323125
# North America                                       13.314153
# Bahamas, The                                        13.223859
# Grenada                                             12.882337
# New Caledonia                                       12.797655
# Fragile and conflict affected situations            12.730672
# Post-demographic dividend                           12.459755
# St. Vincent and the Grenadines                      12.448138
# Sub-Saharan Africa (excluding high income)          12.226746
# Sub-Saharan Africa                                  12.215394
# Sub-Saharan Africa (IDA & IBRD countries)           12.215394
# Antigua and Barbuda                                 12.150439
# Montenegro                                          11.870836
# West Bank and Gaza                                  11.399934
# Timor-Leste                                         11.278942
# Caribbean small states                              10.557423
# St. Kitts and Nevis                                 10.540040
# South Sudan                                         10.267530
# Tuvalu                                               9.949298
# Nauru                                                9.944837
# St. Lucia                                            9.944086
# French Polynesia                                     9.553199
# San Marino                                           9.548233
# Micronesia, Fed. Sts.                                8.940994
# Aruba                                                8.802668
# Pacific island small states                          8.793494
# Palau                                                8.524771
# Turks and Caicos Islands                             8.409606
# Andorra                                              8.239896
# British Virgin Islands                               8.038518
# Guam                                                 7.938291
# Monaco                                               7.891493
# Puerto Rico                                          7.708636
# Bermuda                                              7.376690
# Faroe Islands                                        7.302297
# Gibraltar                                            6.981661
# Cayman Islands                                       6.809587
# American Samoa                                       6.745444
# Greenland                                            6.691395
# Virgin Islands (U.S.)                                6.528253
# Liechtenstein                                        6.277209
# Northern Mariana Islands                             5.890408
# Curacao                                              3.324878
# Kosovo                                               3.277445
# Sint Maarten (Dutch part)                            2.464273
# Isle of Man                                          2.375722
# St. Martin (French part)                             2.104284
# Channel Islands                                      0.000000
# Not classified                                       0.000000

# %%
infra_order.to_csv('../Data/Infrastructure/infrastructure_cov/infra_cov.csv', index = True)

# %% [markdown]
# ## Healthcare Total Expenditure
#
# #### Percent GDP

# %%
h_spend.head()
# Out:
#   LOCATION  INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS  HEALTHEXP     TOT  PC_GDP         A  1971  4.547        NaN
# 1      AUS  HEALTHEXP     TOT  PC_GDP         A  1972  4.547        NaN
# 2      AUS  HEALTHEXP     TOT  PC_GDP         A  1973  4.511        NaN
# 3      AUS  HEALTHEXP     TOT  PC_GDP         A  1974  5.112        NaN
# 4      AUS  HEALTHEXP     TOT  PC_GDP         A  1975  5.760        NaN

# %%
h_spend['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'CHL', 'CHN', 'EST', 'IND', 'IDN',
#        'ISR', 'RUS', 'SVN', 'ZAF', 'COL', 'LVA', 'LTU', 'OAVG', 'CRI',
#        'BGR', 'HRV', 'CYP', 'MLT', 'ROU'], dtype=object)

# %%
h_spend.dtypes
# Out:
# LOCATION       object
# INDICATOR      object
# SUBJECT        object
# MEASURE        object
# FREQUENCY      object
# TIME            int64
# Value         float64
# Flag Codes     object
# dtype: object

# %%
h_spend.isnull().sum()
# Out:
# LOCATION          0
# INDICATOR         0
# SUBJECT           0
# MEASURE           0
# FREQUENCY         0
# TIME              0
# Value             0
# Flag Codes    13859
# dtype: int64

# %%
h_spend.drop(axis = 0, columns = ['FREQUENCY', 'Flag Codes'], inplace = True)

# %%
h_spend = h_spend.set_index('LOCATION')

# %%
h_spend.head()
# Out:
#           INDICATOR SUBJECT MEASURE  TIME  Value
# LOCATION
# AUS       HEALTHEXP     TOT  PC_GDP  1971  4.547
# AUS       HEALTHEXP     TOT  PC_GDP  1972  4.547
# AUS       HEALTHEXP     TOT  PC_GDP  1973  4.511
# AUS       HEALTHEXP     TOT  PC_GDP  1974  5.112
# AUS       HEALTHEXP     TOT  PC_GDP  1975  5.760

# %%
h_spend.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/hspend_clean.csv', index = True)

# %% [markdown]
# **Notes**: Going to have to conver the index 3 letter to actual country name since that's what the other datasets are using. Will be easy once I do country selection and my subset of countries is relatively small. Decided to leave in subject, indicator, and measure for convenience stack. Also a wide range of data for this dataset, going back to 1971 WITH values.

# %% [markdown]
# ### Healthcare Spending COV

# %%
#grouping by location and taking the COV of all values for grouped countries
spend_cov = (h_spend.groupby('LOCATION')['Value'].std()) / (h_spend.groupby('LOCATION')['Value'].mean())
spend_cov = pd.DataFrame(data=spend_cov)

#renaming for readability
spend_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
spend_order = spend_cov.sort_values(by ='COV' , ascending=False)

# %%
spend_order.to_csv('../Data/Infrastructure/infrastructure_cov/spend_cov.csv', index = True)

# %%
#highest 50 COV
spend_order
# Out:
#                COV
# LOCATION
# LUX       2.375354
# IRL       2.271800
# NOR       2.222062
# GBR       2.213435
# USA       2.208883
# DNK       2.194189
# KOR       2.179606
# DEU       2.175834
# JPN       2.147319
# FIN       2.127337
# NZL       2.110088
# AUS       2.084166
# NLD       2.043463
# SWE       2.041311
# CZE       2.024761
# ISL       1.988554
# ESP       1.982093
# FRA       1.976857
# AUT       1.971321
# TUR       1.946248
# CAN       1.933522
# PRT       1.904443
# ITA       1.898562
# POL       1.809955
# SVK       1.776030
# HRV       1.765101
# EST       1.754667
# ROU       1.718227
# BEL       1.711734
# SVN       1.659320
# HUN       1.652760
# ISR       1.644205
# COL       1.639708
# LTU       1.633996
# ZAF       1.600627
# CHE       1.600128
# MLT       1.577861
# CRI       1.561709
# CHL       1.550644
# GRC       1.529266
# RUS       1.521523
# BGR       1.518551
# LVA       1.478707
# CHN       1.465293
# BRA       1.460396
# CYP       1.421193
# MEX       1.359970
# IDN       1.206456
# OAVG      1.039532
# IND       0.992668

# %% [markdown]
# # Pharmaceutical Spending
#
# #### US Dollars / Capita

# %%
pharm_spend.head()
# Out:
#   LOCATION  INDICATOR SUBJECT  MEASURE FREQUENCY  TIME    Value Flag Codes
# 0      AUS  PHARMAEXP     TOT  USD_CAP         A  1998  258.948        NaN
# 1      AUS  PHARMAEXP     TOT  USD_CAP         A  1999  287.245        NaN
# 2      AUS  PHARMAEXP     TOT  USD_CAP         A  2000  338.160        NaN
# 3      AUS  PHARMAEXP     TOT  USD_CAP         A  2001  367.652        NaN
# 4      AUS  PHARMAEXP     TOT  USD_CAP         A  2002  381.433        NaN

# %%
pharm_spend.isnull().sum()
# Out:
# LOCATION        0
# INDICATOR       0
# SUBJECT         0
# MEASURE         0
# FREQUENCY       0
# TIME            0
# Value           0
# Flag Codes    613
# dtype: int64

# %%
pharm_spend['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'EST', 'ISR', 'SVN', 'LVA', 'LTU', 'BGR',
#        'HRV', 'CYP', 'ROU', 'RUS', 'CRI', 'MLT'], dtype=object)

# %%
pharm_spend['TIME'].unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
pharm_spend.drop(axis = 0, columns = ['SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'], inplace = True)

# %%
pharm_spend.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/pharm_spend_clean.csv', index = True)

# %% [markdown]
# ### Pharmaceutical Spending COV

# %%
#grouping by location and taking the COV of all values for grouped countries
pharm_cov = (pharm_spend.groupby('LOCATION')['Value'].std()) / (pharm_spend.groupby('LOCATION')['Value'].mean())
pharm_cov = pd.DataFrame(data=pharm_cov)

#renaming for readability
pharm_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
pharm_order = spend_cov.sort_values(by ='COV' , ascending=False)

# %%
pharm_order.to_csv('../Data/Infrastructure/infrastructure_cov/pharm_cov.csv', index = True)

# %%
pharm_order.head()
# Out:
#                COV
# LOCATION
# LUX       2.375354
# IRL       2.271800
# NOR       2.222062
# GBR       2.213435
# USA       2.208883

# %% [markdown]
# ## Health Indicators
#
# #### Varying Units

# %%
health.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Unmet need for contraception (% of married wom...        SP.UWT.TFRT   NaN
# 1  Completeness of death registration with cause-...     SP.REG.DTHS.ZS   NaN
# 2             Completeness of birth registration (%)     SP.REG.BRTH.ZS   NaN
# 3      Completeness of birth registration, urban (%)  SP.REG.BRTH.UR.ZS   NaN
# 4      Completeness of birth registration, rural (%)  SP.REG.BRTH.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...  2010  2011  2012  2013  2014  2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2016  2017  2018  2019
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 64 columns]

# %%
health.isnull().sum()
# Out:
# Country Name          0
# Country Code          0
# Indicator Name        0
# Indicator Code        0
# 1960              47898
# 1961              48327
# 1962              47847
# 1963              48301
# 1964              48273
# 1965              47907
# 1966              48214
# 1967              47728
# 1968              48172
# 1969              48119
# 1970              47511
# 1971              48023
# 1972              47543
# 1973              47996
# 1974              47960
# 1975              47556
# 1976              47903
# 1977              47409
# 1978              47862
# 1979              47851
# 1980              47173
# 1981              47338
# 1982              46901
# 1983              47298
# 1984              47172
# 1985              46797
# 1986              46774
# 1987              46149
# 1988              46821
# 1989              46654
# 1990              41141
# 1991              43573
# 1992              42788
# 1993              43283
# 1994              43355
# 1995              42505
# 1996              42936
# 1997              42452
# 1998              42894
# 1999              42762
# 2000              27475
# 2001              34385
# 2002              33635
# 2003              33737
# 2004              33571
# 2005              29759
# 2006              32417
# 2007              32518
# 2008              32964
# 2009              32745
# 2010              25441
# 2011              31655
# 2012              31286
# 2013              31827
# 2014              31499
# 2015              27366
# 2016              28072
# 2017              38091
# 2018              45027
# 2019              65744
# dtype: int64

# %%
len(health['Indicator Name'].unique())
# Out:
# 250

# %%
len(health['Country Name'].unique())
# Out:
# 264

# %%
#checked unique indicators
#health['Indicator Name'].unique()

# %% [markdown]
# **Notes**: Most of the data that I want from this dataset can be found in the infrastructure dataset above. Therefore I will likely not be using this dataset.

# %% [markdown]
# ## Hospital Counts
#
# #### Raw Counts

# %%
hosp_count.head()
# Out:
#         VAR   Variable      UNIT Measure  COU    Country   YEA  Year   Value  \
# 0  HOSPTHOS  Hospitals  NOMBRENB  Number  AUS  Australia  2000  2000  1265.0
# 1  HOSPTHOS  Hospitals  NOMBRENB  Number  AUS  Australia  2001  2001  1283.0
# 2  HOSPTHOS  Hospitals  NOMBRENB  Number  AUS  Australia  2002  2002  1284.0
# 3  HOSPTHOS  Hospitals  NOMBRENB  Number  AUS  Australia  2003  2003  1286.0
# 4  HOSPTHOS  Hospitals  NOMBRENB  Number  AUS  Australia  2004  2004  1291.0
#
#   Flag Codes Flags
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN

# %%
hosp_count.dtypes
# Out:
# VAR            object
# Variable       object
# UNIT           object
# Measure        object
# COU            object
# Country        object
# YEA             int64
# Year            int64
# Value         float64
# Flag Codes     object
# Flags          object
# dtype: object

# %%
hosp_count['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Slovak Republic', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States', 'Chile', 'Estonia', 'Israel',
#        'Slovenia', 'Lithuania', 'Latvia'], dtype=object)

# %%
hosp_count.isnull().sum()
# Out:
# VAR              0
# Variable         0
# UNIT             0
# Measure          0
# COU              0
# Country          0
# YEA              0
# Year             0
# Value            0
# Flag Codes    4306
# Flags         4306
# dtype: int64

# %%
hosp_count['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %%
hosp_count.drop(axis = 0, columns = ['VAR', 'UNIT', 'Measure', 'COU', 'YEA', 'Flag Codes', 'Flags'], inplace = True)

# %%
hosp_count = hosp_count.set_index('Country')

# %%
hosp_count.head()
# Out:
#             Variable  Year   Value
# Country
# Australia  Hospitals  2000  1265.0
# Australia  Hospitals  2001  1283.0
# Australia  Hospitals  2002  1284.0
# Australia  Hospitals  2003  1286.0
# Australia  Hospitals  2004  1291.0

# %%
hosp_count.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/hospcount_clean.csv', index = True)

# %% [markdown]
# **Notes**: Pretty straightforward dataset, just counts of hospitals in a country over time. Will likely have the lowest COV among other datasets. Data goes back to 2000.

# %% [markdown]
# ### Hospital COV

# %%
#grouping by location and taking the COV of all values for grouped countries
hosp_cov = (hosp_count.groupby('Country')['Value'].std()) / (hosp_count.groupby('Country')['Value'].mean())
hosp_cov = pd.DataFrame(data=hosp_cov)

#renaming for readability
hosp_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
hosp_order = hosp_cov.sort_values(by ='COV' , ascending=False)

# %%
hosp_order.to_csv('../Data/Infrastructure/infrastructure_cov/hosp_cov.csv', index = True)

# %%
#highest 50 COV
hosp_order
# Out:
#                       COV
# Country
# Netherlands      1.449967
# Korea            1.440981
# Mexico           1.361906
# Turkey           1.339239
# Japan            1.235737
# Italy            1.230184
# United States    1.222081
# Germany          1.220496
# Spain            1.206731
# France           1.206625
# Canada           1.204158
# Australia        1.195225
# Greece           1.154831
# Iceland          1.152590
# Poland           1.142906
# United Kingdom   1.128810
# Czech Republic   1.118954
# Austria          1.094926
# Portugal         1.092298
# Lithuania        1.024580
# Hungary          1.022128
# Israel           1.009369
# Ireland          1.003076
# Belgium          0.989929
# Chile            0.986049
# New Zealand      0.965217
# Finland          0.964724
# Switzerland      0.910013
# Norway           0.899113
# Latvia           0.855941
# Slovenia         0.840293
# Sweden           0.826885
# Luxembourg       0.822204
# Slovak Republic  0.766616
# Estonia          0.725619

# %% [markdown]
# ## Medical Worker Counts
#
# #### Raw Counts

# %%
h_workers.head()
# Out:
#         VAR           Variable      UNIT Measure  COU    Country   YEA  Year  \
# 0  HEDUMEGR  Medical graduates  NOMBRENB  Number  AUS  Australia  2005  2005
# 1  HEDUMEGR  Medical graduates  NOMBRENB  Number  AUS  Australia  2006  2006
# 2  HEDUMEGR  Medical graduates  NOMBRENB  Number  AUS  Australia  2007  2007
# 3  HEDUMEGR  Medical graduates  NOMBRENB  Number  AUS  Australia  2008  2008
# 4  HEDUMEGR  Medical graduates  NOMBRENB  Number  AUS  Australia  2009  2009
#
#     Value Flag Codes Flags
# 0  1798.0        NaN   NaN
# 1  1884.0        NaN   NaN
# 2  2117.0        NaN   NaN
# 3  2389.0        NaN   NaN
# 4  2361.0        NaN   NaN

# %%
h_workers.dtypes
# Out:
# VAR            object
# Variable       object
# UNIT           object
# Measure        object
# COU            object
# Country        object
# YEA             int64
# Year            int64
# Value         float64
# Flag Codes     object
# Flags          object
# dtype: object

# %%
h_workers['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom', 'United States', 'Brazil', 'Chile',
#        "China (People's Republic of)", 'Estonia', 'India', 'Indonesia',
#        'Israel', 'Russia', 'Slovenia', 'South Africa', 'Lithuania',
#        'Latvia', 'Colombia', 'Costa Rica'], dtype=object)

# %%
h_workers.isnull().sum()
# Out:
# VAR               0
# Variable          0
# UNIT              0
# Measure           0
# COU               0
# Country           0
# YEA               0
# Year              0
# Value             2
# Flag Codes    79520
# Flags         79520
# dtype: int64

# %%
h_workers['Year'].unique()
# Out:
# array([2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
h_workers.drop(axis = 0, columns = ['VAR', 'UNIT', 'Measure', 'COU', 'Flag Codes', 'Flags'], inplace = True)

# %%
h_workers = h_workers.set_index('Country')

# %%
h_workers.head()
# Out:
#                     Variable   YEA  Year   Value
# Country
# Australia  Medical graduates  2005  2005  1798.0
# Australia  Medical graduates  2006  2006  1884.0
# Australia  Medical graduates  2007  2007  2117.0
# Australia  Medical graduates  2008  2008  2389.0
# Australia  Medical graduates  2009  2009  2361.0

# %%
h_workers.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/workers_clean.csv', index = True)

# %% [markdown]
# **Notes**: Again a fairly straight forward dataset, just counts for each type of graduates. Unfortunately values start in 2005, will have to figure out how to find data for 2000-2005. Will be feasable once I select my subset of countries.

# %% [markdown]
# ### Medical Workers COV

# %%
#grouping by location and taking the COV of all values for grouped countries
workers_cov = (h_workers.groupby('Country')['Value'].std()) / (h_workers.groupby('Country')['Value'].mean())
workers_cov = pd.DataFrame(data=workers_cov)

#renaming for readability
workers_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
workers_order = workers_cov.sort_values(by ='COV' , ascending=False)

# %%
workers_order.to_csv('../Data/Infrastructure/infrastructure_cov/worker_cov.csv', index = True)

# %%
workers_order
# Out:
#                                    COV
# Country
# Iceland                       6.827375
# Chile                         6.824575
# Hungary                       5.387268
# Denmark                       5.193154
# United Kingdom                4.898067
# Sweden                        4.842242
# Switzerland                   4.348566
# United States                 4.346516
# France                        4.336614
# Norway                        4.222294
# Czech Republic                4.204086
# Germany                       4.121870
# Korea                         4.078239
# Luxembourg                    3.734019
# Netherlands                   3.690612
# Israel                        3.649399
# Japan                         3.646262
# Austria                       3.544116
# Australia                     3.508238
# Latvia                        3.431398
# Italy                         3.415987
# Canada                        3.406531
# Slovenia                      3.381035
# Poland                        3.353574
# New Zealand                   3.320529
# Spain                         3.275637
# Turkey                        3.273396
# Ireland                       3.238867
# Finland                       3.238172
# Lithuania                     3.163814
# Slovak Republic               3.162371
# Belgium                       3.146927
# Portugal                      3.045681
# Estonia                       2.972999
# Mexico                        2.968214
# Greece                        2.958915
# Costa Rica                    2.062657
# Russia                        1.784727
# Brazil                        1.713723
# South Africa                  1.541819
# Colombia                      1.477927
# Indonesia                     1.267130
# China (People's Republic of)  1.171717
# India                         1.165288

# %% [markdown]
# # Doctor Counts
#
# #### Per 1000

# %%
doc_count.head()
# Out:
#   LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS  MEDICALDOC     TOT  1000HAB         A  1999   2.45        NaN
# 1      AUS  MEDICALDOC     TOT  1000HAB         A  2000   2.49        NaN
# 2      AUS  MEDICALDOC     TOT  1000HAB         A  2001   2.56        NaN
# 3      AUS  MEDICALDOC     TOT  1000HAB         A  2002   2.56        NaN
# 4      AUS  MEDICALDOC     TOT  1000HAB         A  2003   2.63        NaN

# %%
doc_count.isnull().sum()
# Out:
# LOCATION        0
# INDICATOR       0
# SUBJECT         0
# MEASURE         0
# FREQUENCY       0
# TIME            0
# Value           0
# Flag Codes    571
# dtype: int64

# %%
doc_count['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX', 'NLD',
#        'NZL', 'NOR', 'POL', 'SVK', 'ESP', 'SWE', 'CHE', 'TUR', 'GBR',
#        'USA', 'BRA', 'CHN', 'EST', 'IND', 'IDN', 'ISR', 'RUS', 'SVN',
#        'ZAF', 'COL', 'LVA', 'LTU'], dtype=object)

# %%
doc_count['TIME'].unique()
# Out:
# array([1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2010, 2018])

# %%
doc_count.drop(axis = 0, columns = ['SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'], inplace = True)

# %%
doc_count.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/doc_count_clean.csv', index = True)

# %% [markdown]
# ### Doctor Count COV

# %%
#grouping by location and taking the COV of all values for grouped countries
doc_cov = (doc_count.groupby('LOCATION')['Value'].std()) / (doc_count.groupby('LOCATION')['Value'].mean())
doc_cov = pd.DataFrame(data=doc_cov)

#renaming for readability
doc_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
doc_order = spend_cov.sort_values(by ='COV' , ascending=False)

# %%
doc_order.to_csv('../Data/Infrastructure/infrastructure_cov/doc_cov.csv', index = True)

# %%
doc_order.head()
# Out:
#                COV
# LOCATION
# LUX       2.375354
# IRL       2.271800
# NOR       2.222062
# GBR       2.213435
# USA       2.208883

# %% [markdown]
# # Nurse Counts
#
# #### Per 1000

# %%
nurse_count.head()
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS     NURSE     TOT  1000HAB         A  1998  10.30        NaN
# 1      AUS     NURSE     TOT  1000HAB         A  1999  10.17        NaN
# 2      AUS     NURSE     TOT  1000HAB         A  2000  10.07        NaN
# 3      AUS     NURSE     TOT  1000HAB         A  2001   9.95        NaN
# 4      AUS     NURSE     TOT  1000HAB         A  2002   9.94        NaN

# %%
nurse_count.isnull().sum()
# Out:
# LOCATION        0
# INDICATOR       0
# SUBJECT         0
# MEASURE         0
# FREQUENCY       0
# TIME            0
# Value           0
# Flag Codes    603
# dtype: int64

# %%
nurse_count['LOCATION'].unique()
# Out:
# array(['AUS', 'AUT', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU', 'GRC',
#        'HUN', 'ISL', 'IRL', 'JPN', 'KOR', 'LUX', 'MEX', 'NLD', 'NZL',
#        'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'CHE', 'TUR', 'GBR', 'USA',
#        'BRA', 'CHN', 'EST', 'IND', 'IDN', 'ISR', 'RUS', 'SVN', 'ZAF',
#        'ITA', 'BEL', 'SWE', 'COL', 'LVA', 'LTU'], dtype=object)

# %%
nurse_count['TIME'].unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2007, 2008, 2009,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2006, 2010, 2018])

# %%
nurse_count.drop(axis = 0, columns = ['SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes'], inplace = True)

# %%
nurse_count.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/nurse_count_clean.csv', index = True)

# %% [markdown]
# ### Nurse Count COV

# %%
#grouping by location and taking the COV of all values for grouped countries
nurse_cov = (nurse_count.groupby('LOCATION')['Value'].std()) / (nurse_count.groupby('LOCATION')['Value'].mean())
nurse_cov = pd.DataFrame(data=nurse_cov)

#renaming for readability
nurse_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
nurse_order = nurse_cov.sort_values(by ='COV' , ascending=False)

# %%
nurse_order.to_csv('../Data/Infrastructure/infrastructure_cov/nurse_cov.csv', index = True)

# %%
nurse_order.head()
# Out:
#                COV
# LOCATION
# BRA       0.494020
# CHN       0.395138
# COL       0.342354
# IND       0.283637
# KOR       0.274460

# %% [markdown]
# ## Medical Technology Counts
#
# #### Raw Counts

# %%
h_tech.head()
# Out:
#         VAR                             Variable      UNIT Measure  COU  \
# 0  IPINSCAN  Computed Tomography scanners, total  NOMBRENB  Number  AUS
# 1  IPINSCAN  Computed Tomography scanners, total  NOMBRENB  Number  AUS
# 2  IPINSCAN  Computed Tomography scanners, total  NOMBRENB  Number  AUS
# 3  IPINSCAN  Computed Tomography scanners, total  NOMBRENB  Number  AUS
# 4  IPINSCAN  Computed Tomography scanners, total  NOMBRENB  Number  AUS
#
#      Country   YEA  Year  Value Flag Codes            Flags
# 0  Australia  2000  2000  500.0          E  Estimated value
# 1  Australia  2001  2001  560.0          E  Estimated value
# 2  Australia  2002  2002  670.0          E  Estimated value
# 3  Australia  2003  2003  800.0          E  Estimated value
# 4  Australia  2004  2004  910.0          E  Estimated value

# %%
h_tech.dtypes
# Out:
# VAR            object
# Variable       object
# UNIT           object
# Measure        object
# COU            object
# Country        object
# YEA             int64
# Year            int64
# Value         float64
# Flag Codes     object
# Flags          object
# dtype: object

# %%
h_tech['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Poland', 'Portugal',
#        'Slovak Republic', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Kingdom', 'United States', 'Brazil', 'Chile', 'Estonia',
#        'Israel', 'Russia', 'Slovenia', 'Latvia', 'Lithuania', 'Colombia',
#        'Costa Rica'], dtype=object)

# %%
h_tech.isnull().sum()
# Out:
# VAR               0
# Variable          0
# UNIT              0
# Measure           0
# COU               0
# Country           0
# YEA               0
# Year              0
# Value             0
# Flag Codes    12466
# Flags         12466
# dtype: int64

# %%
h_tech['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2007, 2008])

# %%
h_tech.drop(axis = 0, columns = ['VAR', 'UNIT', 'Measure', 'COU', 'Flag Codes', 'YEA', 'Flags'], inplace = True)

# %%
h_tech = h_tech.set_index('Country')

# %%
h_tech.head()
# Out:
#                                       Variable  Year  Value
# Country
# Australia  Computed Tomography scanners, total  2000  500.0
# Australia  Computed Tomography scanners, total  2001  560.0
# Australia  Computed Tomography scanners, total  2002  670.0
# Australia  Computed Tomography scanners, total  2003  800.0
# Australia  Computed Tomography scanners, total  2004  910.0

# %%
h_tech.to_csv('../Data/Infrastructure/Cleaned_Infrastructure/tech_clean.csv', index = True)

# %% [markdown]
# **Notes**: Another count dataset with data from 2000 to now.

# %% [markdown]
# ### Medical Technology COV

# %%
#grouping by location and taking the COV of all values for grouped countries
tech_cov = (h_tech.groupby('Country')['Value'].std()) / (h_tech.groupby('Country')['Value'].mean())
tech_cov = pd.DataFrame(data=tech_cov)

#renaming for readability
tech_cov.rename(columns={"Value": "COV"}, inplace = True)

#creating a dataframe that is ordered by COV and not alphabetically.
tech_order = tech_cov.sort_values(by ='COV' , ascending=False)

# %%
tech_order.to_csv('../Data/Infrastructure/infrastructure_cov/tech_cov.csv', index = True)

# %%
#highest 50 COV
tech_order
# Out:
#                       COV
# Country
# Mexico           2.168663
# Chile            1.755242
# Korea            1.712309
# Japan            1.681581
# Canada           1.609451
# France           1.598685
# Poland           1.559945
# Italy            1.537384
# Australia        1.537054
# Finland          1.511528
# Greece           1.500681
# Israel           1.483207
# Colombia         1.482201
# Spain            1.466104
# Russia           1.453200
# Denmark          1.427482
# Portugal         1.424535
# Turkey           1.397908
# Lithuania        1.386403
# Netherlands      1.384177
# Austria          1.381010
# United States    1.372259
# Germany          1.369777
# Latvia           1.337513
# Slovak Republic  1.274289
# Czech Republic   1.266330
# Hungary          1.249417
# Switzerland      1.241003
# Brazil           1.234981
# Costa Rica       1.203856
# Estonia          1.170103
# Iceland          1.167719
# Belgium          1.115517
# Sweden           1.096807
# United Kingdom   1.074855
# Luxembourg       1.070011
# New Zealand      1.019461
# Ireland          0.996249
# Slovenia         0.950987

# %%
#lowest 50 COV
tech_order
# Out:
#                       COV
# Country
# Mexico           2.168663
# Chile            1.755242
# Korea            1.712309
# Japan            1.681581
# Canada           1.609451
# France           1.598685
# Poland           1.559945
# Italy            1.537384
# Australia        1.537054
# Finland          1.511528
# Greece           1.500681
# Israel           1.483207
# Colombia         1.482201
# Spain            1.466104
# Russia           1.453200
# Denmark          1.427482
# Portugal         1.424535
# Turkey           1.397908
# Lithuania        1.386403
# Netherlands      1.384177
# Austria          1.381010
# United States    1.372259
# Germany          1.369777
# Latvia           1.337513
# Slovak Republic  1.274289
# Czech Republic   1.266330
# Hungary          1.249417
# Switzerland      1.241003
# Brazil           1.234981
# Costa Rica       1.203856
# Estonia          1.170103
# Iceland          1.167719
# Belgium          1.115517
# Sweden           1.096807
# United Kingdom   1.074855
# Luxembourg       1.070011
# New Zealand      1.019461
# Ireland          0.996249
# Slovenia         0.950987

# %% [markdown]
# # Infrastructure Coeffecient of Variation Analysis Findings

# %% [markdown]
# From our initial findings in disease analysis we found that may volatile countries in regards to disease transmission are in the Latin America / Carribean region. We also found previously that many Latin American / Carribean countries have a lot of variation in the number of disease cases over time. For this reason we will aim to focus on a country that exhibits both of these characteristics for a particular or several diseases. For those reasons along with the robustness of data available I think either Mexico or Brazil would be good choices to study.
